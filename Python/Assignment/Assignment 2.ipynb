# %%
#Q1
total_Chocolates=327
number_of_kids=78
remaining_chocolates=total_Chocolates % number_of_kids
print("The number of chocolates remaining with the teacher after distribution is: ", remaining_chocolates)
# Out:
# The number of chocolates remaining with the teacher after distribution is:  15

# %%
#Q2
Customer_name=input("Enter your name: ")
customer_mobile_No=input("Enter your mobile number: ")
customer_age=input("Enter your age: ")
customer_email_id=input("Enter your email id: ")

#Printing thankyou message
print("\nHi"+ Customer_name + "!! Thanks for visiting our restaurant and registering for our lucky draw competition in our 25th Anniversary.")
print("Once the lucky draw results are announced you will receive a message on your mobile number: "+ customer_mobile_No)
print("A detailed description of your gift will be sent to your email id: "+ customer_email_id)
print("Thank you for being a valued customer, "+Customer_name+ "!!")
print("Domino's")
# Out:
# Enter your name: Madhuban
# Enter your mobile number: 8928734900
# Enter your age: 21
# Enter your email id: madhubansahani@gmail.com
#
# HiMadhuban!! Thanks for visiting our restaurant and registering for our lucky draw competition in our 25th Anniversary.
# Once the lucky draw results are announced you will receive a message on your mobile number: 8928734900
# A detailed description of your gift will be sent to your email id: madhubansahani@gmail.com
# Thank you for being a valued customer, Madhuban!!
# Domino's

# %%
#Q2
Customer_name=input("Enter your name: ")
customer_mobile_No=input("Enter your mobile number: ")
customer_age=input("Enter your age: ")
customer_email_id=input("Enter your email id: ")

#Printing thankyou message
print(f"\nHi{Customer_name}!! Thanks for visiting our restaurant and registering for our lucky draw competition in our 25th Anniversary. \nOnce the lucky draw results are announced you will receive a message on your mobile number: {customer_mobile_No} \nA detailed description of your gift will be sent to your email id:{customer_email_id} \nThank you for being a valued customer,{Customer_name}!! \nDomino's")
# Out:
# Enter your name: Madhuban
# Enter your mobile number: 8928734900
# Enter your age: 21
# Enter your email id: madhubansahani22@gmail.com
#
# HiMadhuban!! Thanks for visiting our restaurant and registering for our lucky draw competition in our 25th Anniversary.
# Once the lucky draw results are announced you will receive a message on your mobile number: 8928734900
# A detailed description of your gift will be sent to your email id:madhubansahani22@gmail.com
# Thank you for being a valued customer,Madhuban!!
# Domino's

# %%
#Q3
total_students=60
student_per_team=4
number_of_team=total_students // student_per_team
print("The total number of teams that can be created is: ",number_of_team)
# Out:
# The total number of teams that can be created is:  15

# %%
#Q4
fahrenheit=float(input("Enter the tempratur in Fahrenhiet: "))
celcius=(fahrenheit-32) * 5/9
print(f"The temperature in Celsius is:{celcius: .2f}°C")
# Out:
# Enter the tempratur in Fahrenhiet: 105
# The temperature in Celsius is: 40.56°C
