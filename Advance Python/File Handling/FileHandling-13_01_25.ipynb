# %%
f=open("/content/sample_data/FileHandling.txt","r")
content=f.read()

sentences=[sent.strip() for sent in content.split(".") if sent.strip()]
total_sentences=len(sentences)
print("Total number of sentences: ",total_sentences)

print("------------------------------------------------------")
start_with_a=[i for i in sentences if i.startswith("A")]
count=len(start_with_a)
print("Number of sentences starting with A: ",count)

print("------------------------------------------------------")
print("Total Sentence in file: ")
for i, sentence in enumerate (sentences, 1):
  print(f"{i}. {sentence}")
# Out:
# Total number of sentences:  9
# ------------------------------------------------------
# Number of sentences starting with A:  7
# ------------------------------------------------------
# Total Sentence in file:
# 1. Apple is one of the leading technology companies in the world
# 2. It has revolutionized the way we use devices through its innovative products, such as the iPhone and MacBook
# 3. Another company, Amazon, has significantly impacted e-commerce by providing a platform for millions of sellers and buyers worldwide
# 4. Both companies prioritize innovation
# and customer satisfaction, which has helped them maintain their dominance in their respective industries
# 5. Artificial intelligence is another area of focus for these companies
# 6. Advances in AI have opened new possibilities,
# such as personalized recommendations, voice assistants, and predictive analytics
# 7. Additionally, Apple has heavily invested in privacy and security,
# making it a trusted choice for many users
# 8. Amazon, on the other hand, continues to expand its cloud services through AWS, supporting businesses of all sizes globally
# 9. A significant portion of their success is attributed to their relentless focus on improving user experience and staying ahead of the competition

# %%
class AdvanceFileSystem:
    def create_file(self, file_name, content=""):
        file = open(file_name, "w")
        file.write(content)
        print(f"File '{file_name}' created!!")

    def read_file(self, file_name):
        file = open(file_name, "r")
        print(file.read())

    def append_to_file(self, file_name, content):
        file = open(file_name, "a")
        file.write(content)
        print(f"Content appended to '{file_name}'")

    def overwrite(self, file_name, content):
        file = open(file_name, "w+")
        file.write(content)
        print(f"File '{file_name}' overwritten")


def main():
    fs = AdvanceFileSystem()

    print("------Advance File System------")
    while True:
        print("\nSelect an Operation")
        print("1. Create File \n2. Read File \n3. Append File \n4. Over Write File \n5. Exit")

        choice = input("Enter Your Choice: ")

        if choice == '1':
            file_name = input("Enter the file name: ")
            content = input("Enter content for the file: ")
            fs.create_file(file_name, content)

        elif choice == '2':
            file_name = input("Enter the file name to read: ")
            fs.read_file(file_name)

        elif choice == '3':
            file_name = input("Enter the file name to append: ")
            content = input("Enter content to append: ")
            fs.append_to_file(file_name, content)

        elif choice == '4':
            file_name = input("Enter the file name to overwrite: ")
            content = input("Enter new content to overwrite: ")
            fs.overwrite(file_name, content)

        elif choice == '5':
            print("Exiting....")
            break

        else:
            print("Invalid Choice!!!")


if __name__ == "__main__":
    main()
# Out:
# ------Advance File System------
#
# Select an Operation
# 1. Create File
# 2. Read File
# 3. Append File
# 4. Over Write File
# 5. Exit
# Enter Your Choice: 1
# Enter the file name: File1
# Enter content for the file: Hey this is madhuban
# File 'File1' created!!
#
# Select an Operation
# 1. Create File
# 2. Read File
# 3. Append File
# 4. Over Write File
# 5. Exit
# Enter Your Choice: 2
# Enter the file name to read: File1
# Hey this is madhuban
#
# Select an Operation
# 1. Create File
# 2. Read File
# 3. Append File
# 4. Over Write File
# 5. Exit
# Enter Your Choice: 3
# Enter the file name to append: File1
# Enter content to append: I've build an advance file system
# Content appended to 'File1'
#
# Select an Operation
# 1. Create File
# 2. Read File
# 3. Append File
# 4. Over Write File
# 5. Exit
# Enter Your Choice: 4
# Enter the file name to overwrite: File1
# Enter new content to overwrite: i'm learning python and right now build a advance file system
# File 'File1' overwritten
#
# Select an Operation
# 1. Create File
# 2. Read File
# 3. Append File
# 4. Over Write File
# 5. Exit
# Enter Your Choice: 5
# Exiting....
